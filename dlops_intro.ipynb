# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/juansensio/blog/blob/master/084_dlops_intro/084_dlops_intro.ipynb)

# %% [markdown]
# # DLOps - Introducción

# %% [markdown]
# Con este post arrancamos una nueva serie en la que aprenderemos sobre DLOps. El término DLOps es un derivado de [DevOps](https://es.wikipedia.org/wiki/DevOps#:~:text=DevOps%20(acr%C3%B3nimo%20ingl%C3%A9s%20de%20development,entrega%20continua%20de%20alta%20calidad.)), que a su vez hace referencia al conjunto de herramientas de software que nos ayudan al desarrollo y puesta en producción de código asegurando su robustez y calidad durante todo el ciclo de vida. Si bien existen muchas herramientas y "buenas prácticas" para DevOps, su uso en aplicaciones de Inteligencia Artificial no siempre es directo. Esto es debido a las diferencias fundamentales entre el software tradicional (software 1.0) y el *machine learning* (software 2.0). Así pues, hablaremos sobre MLOps cuando nos refiramos a las herramientas que nos ayuden a desarrollar y poner en producción algoritmos de *machine learning*, o DLOps en el caso del *deep learning*. Estas herramientas incluirán, entre otras, la automatización en el entrenamiento de modelos, versionado de datasets, puesta en producción automatizada y monitoreo de modelos en producción.

# %% [markdown]
# > Esta serie está basada en [este](https://github.com/graviraja/MLOps-Basics) stack. Sin embargo, usaré tecnologías alternativas en ciertos puntos y también los haré en otro orden que, en mi opinión, tiene más sentido y facilita las cosas. Aún así, es un gran recurso para todos los interesados en aprender sobre DLOps.

# %% [markdown]
# ## Objetivo

# %% [markdown]
# El objetivo de esta serie será el de montar, desde cero, una infraestructura completa de *deep learning* con especial foco en la automatización para que puedas aplicarlo a tus proyectos. Para ello, desarrollaremos un clasificador de imágenes de dígitos manuscritos usando el dataset MNIST. Este dataset es muy sencillo lo que nos permitirá trabajar de manera rápida. En una aplicación real, sin embargo, es posible que tengas que generar tu propio dataset recogiendo datos específicos de tu aplicación. El otro principal foco está puesto en la descentralización, de manera que esta infraestructura pueda ser implementada en equipos con responsabilidades separadas: mientras que un equipo de científicos de datos trabaja en los datasets, recogiendo y etiquetando nuevas muestras, otro equipo de ingenieros podrá trabajar en los modelos de manera separada y remota. Por otro lado, un equipo de QA minitorizará los modelos en producción para alertar de cualquier anomalía.

# %% [markdown]
# ## Nuestro primer dataset

# %% [markdown]
# En primer lugar, descargaremos el dataset MNIST.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

#path = '/content/drive/MyDrive/Colab Notebooks/dataset'
# Out:
# Mounted at /content/drive

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

X, y = fetch_openml("mnist_784", version=1, return_X_y=True, as_frame=False)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=10000
)

len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (60000, 10000, 60000, 10000)

# %%
import matplotlib.pyplot as plt
import random

fig = plt.figure(dpi=100)
for ix in range(25):
	ax = plt.subplot(5, 5, ix + 1)
	i = random.randint(0, len(X_train)-1)
	img, label = X_train[i], y_train[i]
	ax.imshow(img.reshape(28,28), cmap='gray')
	ax.set_title(label)
	ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# En nuestra primera iteración, haremos un clasificador binario sencillo que detecte sólo el número 3. Más adelante iremos complicando los requisitos, lo cual nos dará opción a generar diferentes versiones de nuestro dataset y así ver un ejemplo de las herramientas necesarias para ello. Además, nos quedaremos con una pequeña muestra para empezar con un dataset limitado.

# %%
import numpy as np

X_train_3 = X_train[y_train == '3'][:100]
X_train_no_3 = X_train[y_train != '3'][:100]

len(X_train_3), len(X_train_no_3)
# Out:
# (100, 100)

# %%
def plot_samples(X):
	fig = plt.figure(dpi=100)
	for ix in range(25):
		ax = plt.subplot(5, 5, ix + 1)
		i = random.randint(0, len(X)-1)
		img = X[i]
		ax.imshow(img.reshape(28,28), cmap='gray')
		ax.axis('off')
	plt.tight_layout()
	plt.show()

# %%
plot_samples(X_train_3)

# %%
plot_samples(X_train_no_3)

# %% [markdown]
# Ahora guardaremos las imágenes en sendas carpetas, separando además un 20% de las muestras para el conjunto de test. A medida que nuestra aplicación vaya creciendo y siendo usada cada vez más deberemos identificar aquellos ejemplos en los que falla, etiquetarlo e incluirlos en el conjunto de test. Por otro lado, deberemos recoger ejemplos similares, etiquetarlos y añadirlos al conjunto de entrenamiento. De este manera, al re-entrenar los modelos, nos aseguraremos de ir corrigiendo errores de manera adecuada (este proceso se conoce como *active learning*).

# %%
import os
from pathlib import Path
from skimage.io import imsave
import shutil

#path = Path('/content/drive/MyDrive/Colab Notebooks/dataset')
path = Path('dataset')
def generate_dataset(X_train_3, X_train_no_3, test_size):
	shutil.rmtree(path)
	os.makedirs(path, exist_ok=True)

	splits = ['train', 'test']
	for split in splits:
		os.makedirs(path / split, exist_ok=True)
		os.makedirs(path / split / '3', exist_ok=True)
		os.makedirs(path / split / 'no3', exist_ok=True)
		if split == 'train':
			X1, X2 = X_train_3[:-test_size], X_train_no_3[:-test_size]
		else:
			X1, X2 = X_train_3[-test_size:], X_train_no_3[-test_size:]
		for x1, x2 in zip(X1, X2):
			imsave(path / split / '3' / f'{random.randint(0, 99999):05d}.png', x1.reshape(28,28).astype('uint8'))
			imsave(path / split / 'no3' / f'{random.randint(0, 99999):05d}.png', x2.reshape(28,28).astype('uint8'))

# %%
generate_dataset(X_train_3, X_train_no_3, 20)

# %%
from glob import glob

def get_paths():
	train_3 = glob(str(path / 'train' / '3' / '*.png'))
	train_no3 = glob(str(path / 'train' / 'no3' / '*.png'))
	test_3 = glob(str(path / 'test' / '3' / '*.png'))
	test_no3 = glob(str(path / 'test' / 'no3' / '*.png'))
	return train_3, train_no3, test_3, test_no3

train_3, train_no3, test_3, test_no3 = get_paths()

len(train_3), len(train_no3), len(test_3), len(test_no3)
# Out:
# (80, 79, 20, 20)

# %%
from skimage.io import imread

def plot_images(paths):
	fig = plt.figure(dpi=100)
	for ix in range(25):
		ax = plt.subplot(5, 5, ix + 1)
		i = random.randint(0, len(paths)-1)
		img = imread(paths[i])
		ax.imshow(img, cmap='gray')
		ax.axis('off')
	plt.tight_layout()
	plt.show()

# %%
plot_images(train_3)

# %%
plot_images(train_no3)

# %% [markdown]
# ## Versionado de datos

# %% [markdown]
# En este punto hemos generado una primera versión de nuestro dataset que queremos usar para entrenar nuestro primero modelo. Sabemos que en el futuro el dataset irá evolucionando, añadiendo más ejemplos y clases (y en función de la aplicación potencialmente nuevas tareas). La opción más sencilla para manejar esto sería generar un `.zip` con nuestros datos, ponerle un nombre (por ejemplo, mnist-v1.0) y guardarlo en algún servidor al cual puedan acceder los ingeniero de *deep learning* para entrenar modelos. Lo mismo podríamos hacer en el software 1.0 con nuestro código (y durante mucho tiempo así se hizo, incluso quizás hay empresas que aún lo hacen 😂) sin embargo hace tiempo que aprendimos que el uso de herramientas de `control de versión` son mucho más útiles y eficaces. El ejemplo principal es `git`. Así pues, para manejar nuestros datos (y más adelante modelos, métricas e incluso `pipelines` de entrenamiento) usaremos una herramienta de `control de versión` específica para trabajar con grandes datos en entornos de *machine learning* conocida como [dvc](https://dvc.org/). `dvc` trabaja en conjunto con `git`, así que lo primero que necesitaremos será un repositorio de `git`, que puedes alojar en `Github`, para manejar el proyecto.
#
# > En mi caso he creado este [repo](https://github.com/juansensio/dlops) que usaré durante toda la serie de posts.

# %% [markdown]
# Puedes instalar `dvc` con el siguiente comando:
#
# ```
# pip install dvc
# ```
#
# Acto seguido, inicializaremos un repositorio con el comando:
#
# ```
# dvc init
# ```
#
# Deberás ejectuar el comando al mismo nivel que el de git, ya que `dvc` utiliza git para el control de version de los metadatos asociados a los datos (archivos grandes). Esto generará una carpeta `.dvc` y un archivo `.dvcignore` similar a git. Ahora podemos añadir la carpeta con los datos al repositorio con el comando
#
# ```
# dvc add dataset
# ```
#
# El siguiente paso será conectar `dvc` con un servicio de almacenamiento remoto en el que guardar nuestros datos. Puedes utilizar diferentes servicios, [aquí](https://dvc.org/features) tienes una lista. En este caso utilizaremos [firebase](https://firebase.google.com/), ya que más adelante usaremos otras características como la base de datos. Para que `dvc` pueda acceder al `bucket` necesitaremos configurar la variable de entorno `GOOGLE_APPLICATION_CREDENTIALS`, siguiendo la [documentación](https://cloud.google.com/docs/authentication/getting-started#command-line) o descargando las credenciales desde la consola de firebase. Una vez conectado, podremos sincronizar nuestro dataset con el comando:
#
# ```
# dvc push
# ```
#
# Ahora puedes probar a eliminar la carpeta `dataset` y para volver a recuperarla puedes ejecutar
#
# ```
# dvc pull dataset.dvc
# ```
#
# Usaremos `git` para crear una nueva versión con el comando
#
# ```
# git tag -a v0 -m "version 0"
# ```
#
# `git` guardará los archivos específicos de `dvc` del commit con el tag determinado.
#
# ```
# git add .
# git commit -m "primera versión"
# git push
# git push origin --tags
# ```
#
# En este punto, cualquiera con acceso al repositorio de `git` y `dvc` (con las credenciales necesarias de `firebase`) podrá acceder al dataset y a todas sus versiones de manera sencilla y remota para usarlo para entrenar modelos o modificarlo y crear nuevas versiones.
#
# ```
# dvc pull
# ```

# %%
pip install dvc
# Out:
# Collecting dvc
#   Using cached dvc-3.17.0-py3-none-any.whl (421 kB)
# Requirement already satisfied: funcy>=1.14 in c:\users\ujat\anaconda3\lib\site-packages (from dvc) (2.0)
# Collecting dvc-http>=2.29.0
#   Using cached dvc_http-2.30.2-py3-none-any.whl (12 kB)
# Collecting pathspec>=0.10.3
#   Using cached pathspec-0.11.2-py3-none-any.whl (29 kB)
# Collecting iterative-telemetry>=0.0.7
#   Using cached iterative_telemetry-0.0.8-py3-none-any.whl (10 kB)
# Collecting dpath<3,>=2.1.0
#   Using cached dpath-2.1.6-py3-none-any.whl (17 kB)
# Collecting flufl.lock<8,>=5
#   Using cached flufl.lock-7.1.1-py3-none-any.whl (11 kB)
# Collecting rich>=12
#   Using cached rich-13.5.2-py3-none-any.whl (239 kB)
# Collecting pydot>=1.2.4
#   Using cached pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting platformdirs<4,>=3.1.1
#   Using cached platformdirs-3.10.0-py3-none-any.whl (17 kB)
# Collecting hydra-core>=1.1
#   Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Collecting ruamel.yaml>=0.17.11
#   Using cached ruamel.yaml-0.17.32-py3-none-any.whl (112 kB)
# Requirement already satisfied: packaging>=19 in c:\users\ujat\anaconda3\lib\site-packages (from dvc) (21.3)
# Requirement already satisfied: voluptuous>=0.11.7 in c:\users\ujat\anaconda3\lib\site-packages (from dvc) (0.13.1)
# Collecting dvc-render<1,>=0.3.1
#   Using cached dvc_render-0.5.3-py3-none-any.whl (19 kB)
# Collecting grandalf<1,>=0.7
#   Using cached grandalf-0.8-py3-none-any.whl (41 kB)
# Collecting dvc-studio-client<1,>=0.9.2
#   Using cached dvc_studio_client-0.13.0-py3-none-any.whl (12 kB)
# Collecting distro>=1.3
#   Using cached distro-1.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: psutil>=5.8 in c:\users\ujat\anaconda3\lib\site-packages (from dvc) (5.9.5)
# Collecting configobj>=5.0.6
#   Using cached configobj-5.0.8-py2.py3-none-any.whl (36 kB)
# Collecting scmrepo<2,>=1.2.1
#   Using cached scmrepo-1.3.1-py3-none-any.whl (57 kB)
# Requirement already satisfied: networkx>=2.5 in c:\users\ujat\anaconda3\lib\site-packages (from dvc) (2.6.3)
# Collecting flatten-dict<1,>=0.4.1
#   Using cached flatten_dict-0.4.2-py2.py3-none-any.whl (9.7 kB)
# Collecting tomlkit>=0.11.1
#   Using cached tomlkit-0.12.1-py3-none-any.whl (37 kB)
# Requirement already satisfied: shortuuid>=0.5 in c:\users\ujat\anaconda3\lib\site-packages (from dvc) (1.0.11)
# Requirement already satisfied: pygtrie>=2.3.2 in c:\users\ujat\anaconda3\lib\site-packages (from dvc) (2.5.0)
# Requirement already satisfied: colorama>=0.3.9 in c:\users\ujat\anaconda3\lib\site-packages (from dvc) (0.4.4)
# Requirement already satisfied: requests>=2.22 in c:\users\ujat\appdata\roaming\python\python39\site-packages (from dvc) (2.27.1)
# Collecting tabulate>=0.8.7
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting zc.lockfile>=1.2.1
#   Using cached zc.lockfile-3.0.post1-py3-none-any.whl (9.8 kB)
# Collecting shtab<2,>=1.3.4
#   Using cached shtab-1.6.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: tqdm<5,>=4.63.1 in c:\users\ujat\anaconda3\lib\site-packages (from dvc) (4.66.1)
# Requirement already satisfied: pyparsing>=2.4.7 in c:\users\ujat\anaconda3\lib\site-packages (from dvc) (3.0.4)
# Collecting dvc-data<2.16.0,>=2.15.0
#   Using cached dvc_data-2.15.4-py3-none-any.whl (67 kB)
# Collecting dvc-task<1,>=0.3.0
#   Using cached dvc_task-0.3.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: six in c:\users\ujat\appdata\roaming\python\python39\site-packages (from configobj>=5.0.6->dvc) (1.16.0)
# Collecting diskcache>=5.2.1
#   Using cached diskcache-5.6.1-py3-none-any.whl (45 kB)
# Requirement already satisfied: sqltrie<1,>=0.6.0 in c:\users\ujat\anaconda3\lib\site-packages (from dvc-data<2.16.0,>=2.15.0->dvc) (0.7.0)
# Collecting dvc-objects<2,>=1.0.1
#   Using cached dvc_objects-1.0.1-py3-none-any.whl (37 kB)
# Requirement already satisfied: attrs>=21.3.0 in c:\users\ujat\anaconda3\lib\site-packages (from dvc-data<2.16.0,>=2.15.0->dvc) (21.4.0)
# Collecting dictdiffer>=0.8.1
#   Using cached dictdiffer-0.9.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: fsspec[http] in c:\users\ujat\anaconda3\lib\site-packages (from dvc-http>=2.29.0->dvc) (2023.6.0)
# Collecting aiohttp-retry>=2.5.0
#   Using cached aiohttp_retry-2.8.3-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: aiohttp in c:\users\ujat\anaconda3\lib\site-packages (from aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\ujat\appdata\roaming\python\python39\site-packages (from dvc-objects<2,>=1.0.1->dvc-data<2.16.0,>=2.15.0->dvc) (4.1.1)
# Collecting dulwich
#   Using cached dulwich-0.21.5-cp39-cp39-win_amd64.whl (482 kB)
# Requirement already satisfied: kombu<6,>=5.3.0 in c:\users\ujat\anaconda3\lib\site-packages (from dvc-task<1,>=0.3.0->dvc) (5.3.1)
# Collecting celery<6,>=5.3.0
#   Using cached celery-5.3.1-py3-none-any.whl (420 kB)
# Requirement already satisfied: pywin32>=225 in c:\users\ujat\anaconda3\lib\site-packages (from dvc-task<1,>=0.3.0->dvc) (302)
# Requirement already satisfied: click-repl>=0.2.0 in c:\users\ujat\anaconda3\lib\site-packages (from celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc) (0.3.0)
# Requirement already satisfied: vine<6.0,>=5.0.0 in c:\users\ujat\anaconda3\lib\site-packages (from celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc) (5.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ujat\anaconda3\lib\site-packages (from celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc) (2.8.2)
# Requirement already satisfied: billiard<5.0,>=4.1.0 in c:\users\ujat\anaconda3\lib\site-packages (from celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc) (4.1.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ujat\anaconda3\lib\site-packages (from celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc) (2023.3)
# Requirement already satisfied: click-didyoumean>=0.3.0 in c:\users\ujat\anaconda3\lib\site-packages (from celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc) (0.3.0)
# Requirement already satisfied: click-plugins>=1.1.1 in c:\users\ujat\anaconda3\lib\site-packages (from celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc) (1.1.1)
# Requirement already satisfied: click<9.0,>=8.1.2 in c:\users\ujat\anaconda3\lib\site-packages (from celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc) (8.1.7)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in c:\users\ujat\anaconda3\lib\site-packages (from click-repl>=0.2.0->celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc) (3.0.39)
# Collecting atpublic>=2.3
#   Using cached atpublic-4.0-py3-none-any.whl (4.9 kB)
# Collecting omegaconf<2.4,>=2.2
#   Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\ujat\anaconda3\lib\site-packages (from hydra-core>=1.1->dvc) (4.9.3)
# Requirement already satisfied: filelock in c:\users\ujat\anaconda3\lib\site-packages (from iterative-telemetry>=0.0.7->dvc) (3.4.2)
# Requirement already satisfied: appdirs in c:\users\ujat\anaconda3\lib\site-packages (from iterative-telemetry>=0.0.7->dvc) (1.4.4)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in c:\users\ujat\anaconda3\lib\site-packages (from kombu<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc) (5.1.1)
# Requirement already satisfied: PyYAML>=5.1.0 in c:\users\ujat\anaconda3\lib\site-packages (from omegaconf<2.4,>=2.2->hydra-core>=1.1->dvc) (6.0)
# Requirement already satisfied: wcwidth in c:\users\ujat\anaconda3\lib\site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc) (0.2.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ujat\appdata\roaming\python\python39\site-packages (from requests>=2.22->dvc) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ujat\appdata\roaming\python\python39\site-packages (from requests>=2.22->dvc) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ujat\appdata\roaming\python\python39\site-packages (from requests>=2.22->dvc) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ujat\appdata\roaming\python\python39\site-packages (from requests>=2.22->dvc) (1.26.8)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ujat\anaconda3\lib\site-packages (from rich>=12->dvc) (2.16.1)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ujat\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc) (0.1.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\ujat\anaconda3\lib\site-packages (from ruamel.yaml>=0.17.11->dvc) (0.2.7)
# Collecting gitpython>3
#   Using cached GitPython-3.1.32-py3-none-any.whl (188 kB)
# Requirement already satisfied: pygit2>=1.10.0 in c:\users\ujat\anaconda3\lib\site-packages (from scmrepo<2,>=1.2.1->dvc) (1.12.2)
# Collecting asyncssh<3,>=2.13.1
#   Using cached asyncssh-2.13.2-py3-none-any.whl (349 kB)
# Requirement already satisfied: cryptography>=3.1 in c:\users\ujat\anaconda3\lib\site-packages (from asyncssh<3,>=2.13.1->scmrepo<2,>=1.2.1->dvc) (3.4.8)
# Requirement already satisfied: cffi>=1.12 in c:\users\ujat\anaconda3\lib\site-packages (from cryptography>=3.1->asyncssh<3,>=2.13.1->scmrepo<2,>=1.2.1->dvc) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\ujat\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.1->asyncssh<3,>=2.13.1->scmrepo<2,>=1.2.1->dvc) (2.21)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\ujat\anaconda3\lib\site-packages (from gitpython>3->scmrepo<2,>=1.2.1->dvc) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\ujat\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>3->scmrepo<2,>=1.2.1->dvc) (5.0.0)
# Requirement already satisfied: orjson in c:\users\ujat\anaconda3\lib\site-packages (from sqltrie<1,>=0.6.0->dvc-data<2.16.0,>=2.15.0->dvc) (3.9.5)
# Requirement already satisfied: setuptools in c:\users\ujat\appdata\roaming\python\python39\site-packages (from zc.lockfile>=1.2.1->dvc) (60.9.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ujat\anaconda3\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (5.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\ujat\anaconda3\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (4.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ujat\anaconda3\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (1.6.3)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ujat\anaconda3\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (1.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ujat\anaconda3\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (1.2.0)
# Installing collected packages: pathspec, omegaconf, markdown-it-py, gitpython, dvc-objects, dulwich, distro, diskcache, dictdiffer, celery, atpublic, asyncssh, aiohttp-retry, zc.lockfile, tomlkit, tabulate, shtab, scmrepo, ruamel.yaml, rich, pydot, platformdirs, iterative-telemetry, hydra-core, grandalf, flufl.lock, flatten-dict, dvc-task, dvc-studio-client, dvc-render, dvc-http, dvc-data, dpath, configobj, dvc
#   Attempting uninstall: pathspec
#     Found existing installation: pathspec 0.7.0
#     Uninstalling pathspec-0.7.0:
#       Successfully uninstalled pathspec-0.7.0
# Successfully installed aiohttp-retry-2.8.3 asyncssh-2.13.2 atpublic-4.0 celery-5.3.1 configobj-5.0.8 dictdiffer-0.9.0 diskcache-5.6.1 distro-1.8.0 dpath-2.1.6 dulwich-0.21.5 dvc-3.17.0 dvc-data-2.15.4 dvc-http-2.30.2 dvc-objects-1.0.1 dvc-render-0.5.3 dvc-studio-client-0.13.0 dvc-task-0.3.0 flatten-dict-0.4.2 flufl.lock-7.1.1 gitpython-3.1.32 grandalf-0.8 hydra-core-1.3.2 iterative-telemetry-0.0.8 markdown-it-py-3.0.0 omegaconf-2.3.0 pathspec-0.11.2 platformdirs-3.10.0 pydot-1.4.2 rich-13.5.2 ruamel.yaml-0.17.32 scmrepo-1.3.1 shtab-1.6.4 tabulate-0.9.0 tomlkit-0.12.1 zc.lockfile-3.0.post1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !rm -rf .git
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
$ dvc init
# Out:
#   File "<ipython-input-16-4a2029bd158b>", line 1
#     $ dvc init
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Creando nuevas versiones

# %% [markdown]
# Ahora vamos a generar una nueva versión del dataset con 100 muestras más de las que teníamos anteriormente.

# %%
X_train_3 = X_train[y_train == '3'][:200]
X_train_no_3 = X_train[y_train != '3'][:200]

len(X_train_3), len(X_train_no_3)
# Out:
# (200, 200)

# %%
generate_dataset(X_train_3, X_train_no_3, 40)

# %%
train_3, train_no3, test_3, test_no3 = get_paths()

len(train_3), len(train_no3), len(test_3), len(test_no3)
# Out:
# (160, 160, 40, 40)

# %% [markdown]
# Utilizaremos los comando vistos anteriormente para crear una nueva versión:
#
# ```
# dvc add dataset
# dvc push
# git add .
# git commit -m 'nueva version'
# git push
# git tag -a v1 -m "version 1"
# git push origin --tags
# ```
#
# Ahora que tenemos diferentes versiones podemos ir cambiando entre ellas de la siguiente manera.
#
# ```
# git checkout tags/v0
# dvc pull
# ```

# %%
# versión 0 con 80/20 split

train_3, train_no3, test_3, test_no3 = get_paths()

len(train_3), len(train_no3), len(test_3), len(test_no3)
# Out:
# (80, 80, 20, 20)

# %% [markdown]
# ```
# git checkout tags/v1
# dvc pull
# ```

# %%
# versión 1 con 160/40 split

train_3, train_no3, test_3, test_no3 = get_paths()

len(train_3), len(train_no3), len(test_3), len(test_no3)
# Out:
# (160, 160, 40, 40)

# %% [markdown]
# ## Resumen

# %% [markdown]
# En este post hemos aprendido a usar la herramienta de control de versiones [`dvc`](https://dvc.org/), la cual hemos usado para versionar nuestro dataset pero que también usaremos más adelante para versionar modelos, métricas e incluso `pipelines` completas de entrenamiento muy útiles para automatización. En este ejemplo hemos visto como generar varias versiones de un dataset para clasificación binaria de dígitos manuscritos que usaremos de ahora en adelante a medida que vayamos introduciendo técnicas y herramientas de DLOps y el cual iremos modificando (y versionando), añadiendo más ejemplos y más clases.
